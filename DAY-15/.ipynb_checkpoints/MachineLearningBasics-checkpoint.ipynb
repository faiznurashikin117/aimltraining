# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
data={
    'Hours':[1,2,3,4,5,6,7,8],
    'Marks': [25,35,45,50,55,65,70,80]
}
df=pd.DataFrame(data)
df
# Out:
#    Hours  Marks
# 0      1     25
# 1      2     35
# 2      3     45
# 3      4     50
# 4      5     55
# 5      6     65
# 6      7     70
# 7      8     80

# %%
# Step 3: Define Features and Target
X = df[['Hours']]
y=df['Marks']

# %%
# Step 4: Split Data into Train & Test Data
X_train, X_test, y_train, y_test = train_test_split(X,y)
print("Training samples:",len(X_train))
print("Testing samples:",len(X_test))
# Out:
# Training samples: 6
# Testing samples: 2

# %%
# Step 5: create the model ; # Step 6: train them
model=LinearRegression()
model.fit(X_train,y_train)
print("Model trained successfully!")
# Out:
# Model trained successfully!

# %%
y_pred=model.predict(X_test)
print(y_test.values)
print(X_test)
print("Actual:",list(y_test.values))
print("Predicted:",list(y_pred))
# Out:
# [45 80]
#    Hours
# 2      3
# 7      8
# Actual: [np.int64(45), np.int64(80)]
# Predicted: [np.float64(42.352941176470594), np.float64(80.58823529411764)]
