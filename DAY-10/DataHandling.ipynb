# %% [markdown]
# # Data Handling Using Pandas

# %%
import pandas as pd

# %%
df=pd.read_excel("students.xlsx")

# %%
print("Students record as follows:")
# Out:
# Students record as follows:

# %%
df
# Out:
#     Name  Age  Marks
# 0   John   20     85
# 1  Alice   22     90
# 2    Bob   21     78
# 3   Sara   23     92
# 4    Sam   25     90

# %%
display(df)
# Out:
#     Name  Age  Marks
# 0   John   20     85
# 1  Alice   22     90
# 2    Bob   21     78
# 3   Sara   23     92
# 4    Sam   25     90

# %%
display(df.describe())
# Out:
#              Age      Marks
# count   5.000000   5.000000
# mean   22.200000  87.000000
# std     1.923538   5.656854
# min    20.000000  78.000000
# 25%    21.000000  85.000000
# 50%    22.000000  90.000000
# 75%    23.000000  90.000000
# max    25.000000  92.000000

# %%
data=pd.read_csv("Final_data.csv")

# %%
data
# Out:
#          Age  Gender  Weight (kg)  Height (m)  Max_BPM  Avg_BPM  Resting_BPM  \
# 0      34.91    Male        65.27        1.62   188.58   157.65        69.05
# 1      23.37  Female        56.41        1.55   179.43   131.75        73.18
# 2      33.20  Female        58.98        1.67   175.04   123.95        54.96
# 3      38.69  Female        93.78        1.70   191.21   155.10        50.07
# 4      45.09    Male        52.42        1.88   193.58   152.88        70.84
# ...      ...     ...          ...         ...      ...      ...          ...
# 19995  46.77  Female        98.31        1.90   199.20   148.18        63.72
# 19996  40.38  Female        88.12        1.87   196.18   134.18        54.04
# 19997  50.31    Male        46.20        1.67   163.34   157.92        61.65
# 19998  52.36    Male        44.30        1.62   179.27   121.23        60.88
# 19999  29.56    Male        58.63        1.61   198.07   121.74        72.05
#
# ...

# %%
selected_data=data[["Age","Gender","Max_BPM","Avg_BPM"]]

# %%
selected_data.describe()

# %%
df=pd.read_excel("students.xlsx")

# %%
df
# Out:
#     Name  Age  Marks
# 0   John   20     85
# 1  Alice   22     90
# 2    Bob   21     78
# 3   Sara   23     92
# 4    Sam   25     90

# %%
top_students=df[df["Marks"]>80]
top_students
# Out:
#     Name  Age  Marks
# 0   John   20     85
# 1  Alice   22     90
# 3   Sara   23     92
# 4    Sam   25     90

# %%
rejected_students=df[df["Marks"]<=80]

# %%
rejected_students
# Out:
#   Name  Age  Marks
# 2  Bob   21     78

# %%
top_students.to_excel("selected_students.xlsx",index=False)
print("Filtered data saved to 'selected_students.xlsx'")
# Out:
# Filtered data saved to 'selected_students.xlsx'

# %%
rejected_students.to_excel("rejected_students.xlsx",index=False)
print("File Created")
# Out:
# File Created

# %%
rejected_students.to_excel("rejected2_students.xlsx",index=True)
print("File Created 'rejected2_students.xlsx'")
# Out:
# File Created 'rejected2_students.xlsx'

# %% [markdown]
# # # Filter data of persons whose weight greater than 60kg. We want only Age, Gender, Weight (kg), protein_per_kg

# %%
data=pd.read_csv("Final_data.csv")

# %%
selected_data=data[["Age", "Gender", "Weight (kg)","protein_per_kg"]]
Overweight=selected_data[data["Weight (kg)"]>60]
Overweight
# Out:
#          Age  Gender  Weight (kg)  protein_per_kg
# 0      34.91    Male        65.27        1.624789
# 3      38.69  Female        93.78        0.862017
# 5      53.19  Female       105.05        0.646549
# 7      55.92  Female        84.07        1.253836
# 8      24.11  Female        88.58        0.783924
# ...      ...     ...          ...             ...
# 19992  28.59  Female        68.43        1.200058
# 19993  28.52  Female        87.72        1.297424
# 19994  39.38    Male        64.13        1.939498
# 19995  46.77  Female        98.31        0.954837
# 19996  40.38  Female        88.12        0.689060
#
# [14169 rows x 4 columns]

# %%
Overweight.to_excel("Overweight.xlsx",index=False)
print("File Overweight.xlsx Created")
# Out:
# File Overweight.xlsx Created

# %% [markdown]
# # Use patient file and display all records
# ## show number of rows and columns in your dataset

# %%
Pt_data=pd.read_csv("patients.csv")
Pt_data
# Out:
#        patient_id               name  age arrival_date departure_date  \
# 0    PAT-09484753  Richard Rodriguez   24   2025-03-16     2025-03-22
# 1    PAT-f0644084     Shannon Walker    6   2025-12-13     2025-12-14
# 2    PAT-ac6162e4       Julia Torres   24   2025-06-29     2025-07-05
# 3    PAT-3dda2bb5    Crystal Johnson   32   2025-10-12     2025-10-23
# 4    PAT-08591375        Garrett Lin   25   2025-02-18     2025-02-25
# ..            ...                ...  ...          ...            ...
# 995  PAT-a01bf534         Amber Vang   26   2025-12-02     2025-12-04
# 996  PAT-87fa07bd       Martha Smith   89   2025-11-18     2025-11-30
# 997  PAT-8f07e894     Jennifer James   72   2025-12-12     2025-12-21
# 998  PAT-4ae301e1     Kara Hernandez   47   2025-02-08     2025-02-20
# 999  PAT-e2ef9c5f    Lorraine Turner   64   2025-05-04     2025-05-08
#
#               service  satisfaction
# 0             surgery            61
# 1             surgery            83
# ...

# %%
df.shape=num_rows, num_columns
print(f"Number of rows is {num_rows}")
print(f"Number of columns is {num_columns}")
# Out:
# C:\Users\Faridah\AppData\Local\Temp\ipykernel_8188\1245191976.py:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df.shape=num_rows, num_columns
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name, value)
#    6339                         stacklevel=find_stack_level(),
#    6340                     )
# -> 6341                 object.__setattr__(self, name, value)
#
# AttributeError: property 'shape' of 'DataFrame' object has no setter
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8188\1245191976.py in ?()
# ----> 1 df.shape=num_rows, num_columns
# ...

# %% [markdown]
# # Create the list of patients, those are in ICU
# ## save the file with the name icu_patients.csv

# %%
icu_pt=Pt_data[Pt_data["service"]=="ICU"]
icu_pt
# Out:
#        patient_id               name  age arrival_date departure_date service  \
# 4    PAT-08591375        Garrett Lin   25   2025-02-18     2025-02-25     ICU
# 7    PAT-5b61868c      Ashley Waller    0   2025-05-21     2025-06-04     ICU
# 10   PAT-003ce690        Larry Dixon   29   2025-01-19     2025-01-21     ICU
# 20   PAT-5e3f8747   Elizabeth Kelley   34   2025-03-29     2025-04-12     ICU
# 24   PAT-f70aeea1    Rebecca Jackson   18   2025-02-05     2025-02-18     ICU
# ..            ...                ...  ...          ...            ...     ...
# 990  PAT-110d5794        Travis Hull   48   2025-11-12     2025-11-18     ICU
# 992  PAT-8700b93a  Nicholas Lawrence    9   2025-10-25     2025-11-02     ICU
# 993  PAT-e5d6a9cf       Jacob Santos   76   2025-12-27     2026-01-02     ICU
# 997  PAT-8f07e894     Jennifer James   72   2025-12-12     2025-12-21     ICU
# 998  PAT-4ae301e1     Kara Hernandez   47   2025-02-08     2025-02-20     ICU
#
#      satisfaction
# ...

# %%
icu_patients.to_csv("icu_patients.csv",index=False)

# %%
print("File icu_patients.csv is created")
# Out:
# File icu_patients.csv is created

# %%
Pt_data.head(0)
# Out:
# Empty DataFrame
# Columns: [patient_id, name, age, arrival_date, departure_date, service, satisfaction]
# Index: []

# %%
Pt_data.head(10)
# Out:
#      patient_id               name  age arrival_date departure_date  \
# 0  PAT-09484753  Richard Rodriguez   24   2025-03-16     2025-03-22
# 1  PAT-f0644084     Shannon Walker    6   2025-12-13     2025-12-14
# 2  PAT-ac6162e4       Julia Torres   24   2025-06-29     2025-07-05
# 3  PAT-3dda2bb5    Crystal Johnson   32   2025-10-12     2025-10-23
# 4  PAT-08591375        Garrett Lin   25   2025-02-18     2025-02-25
# 5  PAT-f4b29bae          Diana May   83   2025-06-26     2025-06-30
# 6  PAT-283cda07    William Herrera   62   2025-12-26     2025-12-27
# 7  PAT-5b61868c      Ashley Waller    0   2025-05-21     2025-06-04
# 8  PAT-f9c8afa6       Victor Baker   50   2025-07-30     2025-08-13
# 9  PAT-5290be70   Jeffrey Chandler   29   2025-11-01     2025-11-14
#
#             service  satisfaction
# 0           surgery            61
# 1           surgery            83
# 2  general_medicine            83
# 3         emergency            81
# 4               ICU            76
# ...
